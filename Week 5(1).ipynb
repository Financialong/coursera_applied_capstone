# %% [markdown]
# # The Chinese Restaurants Battle in Hong Kong (Week 2) with Code
#
# ##### Bryan Kwok - 2020/11/06

# %% [markdown]
# ## Introduction
#
# People always come up with a place in the world with various cultures and languages in a place, which is Hong Kong. Although the size of Hong Kong is relatively small to some countries in Europe, there are over 7.5 million people in 18 districts here. This is a place inherited ancient Chinese culture and experienced a period of western colonial influence.
#
# There are so many good restaurants in Hong Kong, including Chinese, Japanese, Western, etc. Many investors in the world would like to build up their reputation in Hong Kong and set up a restaurant here. However, it is never easy to survive in this battlefield without research and delicious food. Chinese restaurants will be one of the good choices for HongKongers based on its appealing dishes and fresh ingredients.
#
# In this project, we will try to investigate the neighborhoods in the districts of Hong Kong.  By the end, we will solve the problems, and tell you the good choice of opening a Chinese restaurant in Hong Kong.

# %% [markdown]
# ## Business Problem
#
# The objective of this project is to find out the optimum place in Hong Kong to open a new Chinese restaurant. For investors, it would be critical for them to know which places are important to have the new restaurants. It may be also important for them to set up a restaurant with similar dishes around the districts. Some districts may probably have more good Chinese restaurants compared to the others. This may help them stand out and build the reputation.
#
# For us, it is always helpful to have more information of good Chinese restaurants. This project will also provide a good insight for audience to understand the distribution of Chinese restaurants in Hong Kong.

# %% [markdown]
# ### Problem Statement
#
# 1. Where are the best districts for Chinese cuisine in Hong Kong?
# 2. In disticts should the investor open a Chinese restaurant to have the best chance of being successful?
# 3. Where can we go in Hong Kong to have the best Chinese food?

# %% [markdown]
# ## Data
#
# To solve the business problem, the following data is required for analysis.
#
# - The data of Hong Kong containing the districts name
# - Latitude and Longitude coordinates of those districts
# - Venue places with the information of location, name, categories

# %% [markdown]
# ## Methodology
#
# - Firstly, the data will be collected from _https://www.geodatos.net/en/coordinates/hong-kong_ and cleaned for the later process.
#
# - Then FourSquare will be used to locate the venues in those districts. Then the number and frequencies of restaurant types will be recorded and summarized into the dataframe.
#
# - Data will be sorted based on rankings. At the end, the data will be visually visualized by the graphics using the Python libraries.

# %%
import pandas as pd
import numpy as np # library to handle data in a vectorized manner
import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline

import seaborn as sns

#print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude


def get_venues(lat,lng):
    #set variables
    radius=400
    LIMIT=100
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df


def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
#Getting the geographical coordinates from csv files
myhk_df = pd.read_csv('hk_geog.csv')
myhk_df.head()
# Out:
#                 City          Coordinates
# 0          Hong Kong  22.27832, 114.17469
# 1            Kowloon  22.31667, 114.18333
# 2          Tsuen Wan  22.37137, 114.11329
# 3  Yuen Long Kau Hui     22.45, 114.03333
# 4         Tung Chung  22.28783, 113.94243

# %%
myhk_df[['Latitude','Longitude']] = myhk_df['Coordinates'].str.split(', ',expand=True)
#myhk_df = myhk_df[['City','Latitude','Longitude']]

myhk_df.head()
#myhk_df = myhk_df.convert_objects(convert_numeric=True)
myhk_df['Latitude'] = myhk_df['Latitude'].astype('float')
myhk_df['Longitude'] = myhk_df['Longitude'].astype('float')
myhk_df.head()
# Out:
#                 City          Coordinates  Latitude  Longitude
# 0          Hong Kong  22.27832, 114.17469  22.27832  114.17469
# 1            Kowloon  22.31667, 114.18333  22.31667  114.18333
# 2          Tsuen Wan  22.37137, 114.11329  22.37137  114.11329
# 3  Yuen Long Kau Hui     22.45, 114.03333  22.45000  114.03333
# 4         Tung Chung  22.28783, 113.94243  22.28783  113.94243

# %%
print('The dataframe has {} districts.'.format(
        len(myhk_df['City'].unique()),
        myhk_df.shape[0]
    )
)
# Out:
# The dataframe has 17 districts.

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID:
# CLIENT_SECRET:

# %%
column_names=['City','ID','Name']
chinese_rest_hk=pd.DataFrame(columns=column_names)
count = 1
for row in myhk_df.values.tolist():
    City, Coordinates, Latitude, Longitude = row
    venues = get_venues(Latitude,Longitude)
    chinese_restaurants = venues[venues['Category']=='Chinese Restaurant']
    print('(',count,'/',len(myhk_df),')','Chinese Restaurants in '+ City +', '+':'+str(len(chinese_restaurants)))
    print(row)
    for resturant_detail in chinese_restaurants.values.tolist():
        id, name , category=resturant_detail
        chinese_rest_hk = chinese_rest_hk.append({'City': City,
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 17 ) Chinese Restaurants in Hong Kong, :2
# ['Hong Kong', '22.27832, 114.17469', 22.27832, 114.17469]
# ( 2 / 17 ) Chinese Restaurants in Kowloon, :0
# ['Kowloon', '22.31667, 114.18333', 22.31667, 114.18333]
# ( 3 / 17 ) Chinese Restaurants in Tsuen Wan, :3
# ['Tsuen Wan', '22.37137, 114.11329', 22.37137, 114.11329]
# ( 4 / 17 ) Chinese Restaurants in Yuen Long Kau Hui, :0
# ['Yuen Long Kau Hui', '22.45, 114.03333', 22.45, 114.03333]
# ( 5 / 17 ) Chinese Restaurants in Tung Chung, :3
# ['Tung Chung', '22.28783, 113.94243', 22.28783, 113.94243]
# ( 6 / 17 ) Chinese Restaurants in Sha Tin, :0
# ['Sha Tin', '22.38333, 114.18333', 22.38333, 114.18333]
# ( 7 / 17 ) Chinese Restaurants in Tuen Mun, :0
# ['Tuen Mun', '22.39175, 113.97157', 22.39175, 113.97157]
# ( 8 / 17 ) Chinese Restaurants in Tai Po, :4
# ['Tai Po', '22.45007, 114.16877', 22.45007, 114.16877]
# ( 9 / 17 ) Chinese Restaurants in Sai Kung, :0
# ['Sai Kung', '22.38333, 114.26667', 22.38333, 114.26667]
# ( 10 / 17 ) Chinese Restaurants in Yung Shue Wan, :2
# ['Yung Shue Wan', '22.22623, 114.11241', 22.22623, 114.11241]
# ( 11 / 17 ) Chinese Restaurants in Ngong Ping, :2
# ['Ngong Ping', '22.25556, 113.90391', 22.25556, 113.90391]
# ( 12 / 17 ) Chinese Restaurants in Sok Kwu Wan, :0
# ['Sok Kwu Wan', '22.20453, 114.13159', 22.20453, 114.13159]
# ( 13 / 17 ) Chinese Restaurants in Tai O, :2
# ['Tai O', '22.25515, 113.86309', 22.25515, 113.86309]
# ( 14 / 17 ) Chinese Restaurants in Central, :4
# ['Central', '22.28299, 114.15846', 22.28299, 114.15846]
# ( 15 / 17 ) Chinese Restaurants in Wan Chai, :2
# ['Wan Chai', '22.28142, 114.17258', 22.28142, 114.17258]
# ( 16 / 17 ) Chinese Restaurants in Sham Shui Po, :2
# ['Sham Shui Po', '22.33023, 114.15945', 22.33023, 114.15945]
# ( 17 / 17 ) Chinese Restaurants in Wong Tai Sin, :0
# ['Wong Tai Sin', '22.35, 114.18333', 22.35, 114.18333]

# %%
# Save the information so far to a .csv file due to limited calls on FourSquare
chinese_rest_hk.to_csv('chinese_rest_hk.csv')

# %%
chinese_hk = pd.read_csv('chinese_rest_hk.csv')
chinese_hk
# Out:
#     Unnamed: 0           City                        ID  \
# 0            0      Hong Kong  4b67b864f964a520f15b2be3
# 1            1      Hong Kong  4bb2cdfb715eef3b41bf85bb
# 2            2      Tsuen Wan  4d400e3789616dcb823f00b5
# 3            3      Tsuen Wan  4be40308b02ec9b684c450c0
# 4            4      Tsuen Wan  4e33f15062e1733d7aa708c4
# 5            5     Tung Chung  4d16c7aab15cb1f737efaf21
# 6            6     Tung Chung  4c936bcd1221b1f768cf19e2
# 7            7     Tung Chung  5243fe4711d27f0bc9d8d08d
# 8            8         Tai Po  4e89b10d6c25bf8636514f83
# 9            9         Tai Po  4bf0eb5fb315c9b6c97f93ff
# 10          10         Tai Po  4d06140e37036dcb43ff19fb
# 11          11         Tai Po  4c86006b2f1c236af53c5943
# 12          12  Yung Shue Wan  4bc307e84cdfc9b613be9621
# 13          13  Yung Shue Wan  4d4007211bd2a143b884ee7c
# 14          14     Ngong Ping  4c1b0402eac020a1f74744c2
# 15          15     Ngong Ping  5296c17c498e6bae2ed31b3c
# 16          16          Tai O  4cba94d4f50e224b6fecf4fb
# 17          17          Tai O  5063e14ee4b05840d81e4b36
# 18          18        Central  5288ad13498e14da0d2188fd
# 19          19        Central  5662695e498ee423e725baf7
# 20          20        Central  51937957498e1228fa669b99
# 21          21        Central  4b91df7ef964a520eedc33e3
# 22          22       Wan Chai  4b0588d8f964a520d5dc22e3
# 23          23       Wan Chai  4b67b864f964a520f15b2be3
# 24          24   Sham Shui Po  4cda99864006a14382a4d2b2
# 25          25   Sham Shui Po  50dd8548e4b021301ef05370
#
#                                     Name
# 0               Liu Yuan Pavilion (留園雅敘)
# 1           Trusty Congee King (靠得住粥麵小館)
# 2         Nice Capital Restaurant (麗都讌客)
# 3      Sportful Garden Restaurant (陶源酒家)
# 4          The Great Restaurant (一品雞煲火鍋)
# 5                        Super Super 一粥麵
# 6   Federal Palace (Federal Palace 聯邦皇宮)
# 7                       Old Cheng Du 老城都
# 8                     China House (家傳滬曉)
# 9                       Kwan Kee (群記清湯腩)
# 10                 Tong Kee Bao Dim 唐記包點
# 11                                 新明發食家
# 12         Lung Kong Restaurant (龍江川粵菜館)
# 13                                  蔡記小食
# 14   Ngong Ping Garden Restaurant (昂坪膳坊)
# 15               Feng Chia Market (逢甲工房)
# 16       Fook Moon Lam Restaurant  福滿林酒樓
# 17                                  金培餐廳
# 18                      China Tang (唐人館)
# 19               Howard's Gourmet (好酒好蔡)
# 20                     Duddell's (都爹利會館)
# 21                 Cuisine Cuisine (國金軒)
# 22               One Harbour Road (港灣壹號)
# 23              Liu Yuan Pavilion (留園雅敘)
# 24                   Shia Wong Hip (蛇王協)
# 25                              利星海鮮小炒火鍋

# %%
chinese_hk.columns = ['Index','City','ID','Name']
chinese_hk.shape
# Out:
# (26, 4)

# %%
chinese_rest_hk.groupby('City')['ID'].count().plot.bar(figsize=(10,5), color='lightblue')
plt.title('Number of Chinese Restaurants in Hong Kong', fontsize = 20)
plt.xlabel('District', fontsize = 15)
plt.ylabel('No. of Chinese Restaurants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()

# %% [markdown]
# Now we will get the ranking of each restaurant for further analysis.

# %%
chinese_hk
# Out:
#     Index           City                        ID  \
# 0       0      Hong Kong  4b67b864f964a520f15b2be3
# 1       1      Hong Kong  4bb2cdfb715eef3b41bf85bb
# 2       2      Tsuen Wan  4d400e3789616dcb823f00b5
# 3       3      Tsuen Wan  4be40308b02ec9b684c450c0
# 4       4      Tsuen Wan  4e33f15062e1733d7aa708c4
# 5       5     Tung Chung  4d16c7aab15cb1f737efaf21
# 6       6     Tung Chung  4c936bcd1221b1f768cf19e2
# 7       7     Tung Chung  5243fe4711d27f0bc9d8d08d
# 8       8         Tai Po  4e89b10d6c25bf8636514f83
# 9       9         Tai Po  4bf0eb5fb315c9b6c97f93ff
# 10     10         Tai Po  4d06140e37036dcb43ff19fb
# 11     11         Tai Po  4c86006b2f1c236af53c5943
# 12     12  Yung Shue Wan  4bc307e84cdfc9b613be9621
# 13     13  Yung Shue Wan  4d4007211bd2a143b884ee7c
# 14     14     Ngong Ping  4c1b0402eac020a1f74744c2
# 15     15     Ngong Ping  5296c17c498e6bae2ed31b3c
# 16     16          Tai O  4cba94d4f50e224b6fecf4fb
# 17     17          Tai O  5063e14ee4b05840d81e4b36
# 18     18        Central  5288ad13498e14da0d2188fd
# 19     19        Central  5662695e498ee423e725baf7
# 20     20        Central  51937957498e1228fa669b99
# 21     21        Central  4b91df7ef964a520eedc33e3
# 22     22       Wan Chai  4b0588d8f964a520d5dc22e3
# 23     23       Wan Chai  4b67b864f964a520f15b2be3
# 24     24   Sham Shui Po  4cda99864006a14382a4d2b2
# 25     25   Sham Shui Po  50dd8548e4b021301ef05370
#
#                                     Name
# 0               Liu Yuan Pavilion (留園雅敘)
# 1           Trusty Congee King (靠得住粥麵小館)
# 2         Nice Capital Restaurant (麗都讌客)
# 3      Sportful Garden Restaurant (陶源酒家)
# 4          The Great Restaurant (一品雞煲火鍋)
# 5                        Super Super 一粥麵
# 6   Federal Palace (Federal Palace 聯邦皇宮)
# 7                       Old Cheng Du 老城都
# 8                     China House (家傳滬曉)
# 9                       Kwan Kee (群記清湯腩)
# 10                 Tong Kee Bao Dim 唐記包點
# 11                                 新明發食家
# 12         Lung Kong Restaurant (龍江川粵菜館)
# 13                                  蔡記小食
# 14   Ngong Ping Garden Restaurant (昂坪膳坊)
# 15               Feng Chia Market (逢甲工房)
# 16       Fook Moon Lam Restaurant  福滿林酒樓
# 17                                  金培餐廳
# 18                      China Tang (唐人館)
# 19               Howard's Gourmet (好酒好蔡)
# 20                     Duddell's (都爹利會館)
# 21                 Cuisine Cuisine (國金軒)
# 22               One Harbour Road (港灣壹號)
# 23              Liu Yuan Pavilion (留園雅敘)
# 24                   Shia Wong Hip (蛇王協)
# 25                              利星海鮮小炒火鍋

# %%
column_names=['City', 'ID','Name','Likes','Rating','Tips']
chinese_rest_stats_hk=pd.DataFrame(columns=column_names)

count=1
for row in chinese_hk.values.tolist():
    Index, City ,ID ,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id ,name ,likes ,rating ,tips =[0]*5
    print('(',count,'/',len(chinese_rest_hk),')','processed')
    chinese_rest_stats_hk = chinese_rest_stats_hk.append({'City': City, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
chinese_rest_stats_hk.tail()
# Out:
# {'meta': {'code': 200, 'requestId': '5fa5010c7fff582585ab23c2'}, 'response': {'venue': {'id': '4b67b864f964a520f15b2be3', 'name': 'Liu Yuan Pavilion (留園雅敘)', 'contact': {'phone': '+85228042000', 'formattedPhone': '+852 2804 2000'}, 'location': {'address': '3/F, The Broadway, 54-62 Lockhart Rd', 'lat': 22.278207847994896, 'lng': 114.1708592923482, 'labeledLatLngs': [{'label': 'display', 'lat': 22.278207847994896, 'lng': 114.1708592923482}], 'cc': 'HK', 'neighborhood': 'Wan Chai', 'city': '灣仔', 'state': '灣仔區', 'country': '香港', 'formattedAddress': ['3/F, The Broadway, 54-62 Lockhart Rd', '灣仔區', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/liu-yuan-pavilion/4b67b864f964a520f15b2be3', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 24}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 35, 'groups': [{'type': 'others', 'count': 35, 'items': []}], 'summary': '35 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.2, 'ratingColor': '73CF42', 'ratingSignals': 59, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 171, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 171, 'items': [{'id': '50c343ebe4b0de89d000a836', 'createdAt': 1354974187, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4250146_mUyWNY10PcxlfAlG31mqa2ICmrbAutDDcZEFm_qNFpM.jpg', 'width': 675, 'height': 720, 'user': {'id': '4250146', 'isSanctioned': False, 'firstName': 'ju', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/UODUC2NMTKJOH5YT.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1265088612, 'tips': {'count': 24, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 24, 'items': [{'id': '525e32a5498e3979565e6d76', 'createdAt': 1381905061, 'text': 'Probably best Xiao Lung Bao outside of Din Tai Fung and quietest Chinese restaurant in HK with a more modern layout.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/525e32a5498e3979565e6d76', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '4242981', 'isSanctioned': False, 'firstName': 'Tagu', 'lastName': 'H', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/GHN02D2JCKGK41B2.jpg'}}, {'id': '1104799', 'isSanctioned': False, 'firstName': 'Stephen', 'lastName': 'F', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/HD1F1CDHHADFINOR.png'}}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '20563', 'isSanctioned': False, 'firstName': 'Casey', 'lastName': 'L', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/XEI5YTCXK2HRJSSM.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/a6nBsN', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 83, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 83, 'items': [{'id': '510cdbdde4b036b55595bf9a', 'name': 'HK - Resto to Try (HK Island)', 'description': "Restaurants on HK Island side can't wait to try! Bon Appétit :) Read my restaurant reviews on www.foodcraver.hk", 'entities': [{'indices': [94, 111], 'type': 'url', 'object': {'url': 'http://www.foodcraver.hk'}}], 'type': 'others', 'user': {'id': '12005011', 'isSanctioned': False, 'firstName': 'Food', 'lastName': 'C', 'photo': {'prefix': 'https://fastly.4sqi.net/img/u ...
#                          ID                      Name  Likes  Rating  Tips
# 0  4b67b864f964a520f15b2be3  Liu Yuan Pavilion (留園雅敘)     35     8.2    24
# ( 1 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa5010c90fd6244ff3cc374'}, 'response': {'venue': {'id': '4bb2cdfb715eef3b41bf85bb', 'name': 'Trusty Congee King (靠得住粥麵小館)', 'contact': {'phone': '+85228823268', 'formattedPhone': '+852 2882 3268', 'facebook': '188808891165045', 'facebookUsername': 'tckhk', 'facebookName': '靠得住粥麵小館'}, 'location': {'address': 'G/F, 7 Heard St', 'lat': 22.277550315953565, 'lng': 114.17718030957542, 'labeledLatLngs': [{'label': 'display', 'lat': 22.277550315953565, 'lng': 114.17718030957542}], 'cc': 'HK', 'neighborhood': 'Wan Chai District', 'city': '香港', 'country': '香港', 'formattedAddress': ['G/F, 7 Heard St', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/trusty-congee-king/4bb2cdfb715eef3b41bf85bb', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 17}, 'url': 'http://www.tck.hk', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 30, 'groups': [{'type': 'others', 'count': 30, 'items': []}], 'summary': '30 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 45, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 146, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 146, 'items': [{'id': '51dd6f1d498e223d3271f708', 'createdAt': 1373466397, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/957171_Wj8ztV53sbYZc2Bq6Xcf6ktvnoafvICW5yICq_tEqg4.jpg', 'width': 612, 'height': 612, 'user': {'id': '957171', 'isSanctioned': False, 'firstName': 'Jacky', 'lastName': 'L', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/Q2XYELVMHUWCYS43.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1270009339, 'tips': {'count': 17, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 17, 'items': [{'id': '54c121b9498e6e802d92dec4', 'createdAt': 1421943225, 'text': 'Liver and Fish belly congee is always delicious here. Rarely have to wait for a table. Always high quality congee.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/54c121b9498e6e802d92dec4', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '47990999', 'isSanctioned': False, 'firstName': 'Jun', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/47990999_ygWRSkKv_ZiffRowh2GES5FBL2E0tktWUdqk4MOXYx0Cv0veYoLgxQdwQk-rAxDiXm-HWC3yu.jpg'}}, {'id': '75942280', 'isSanctioned': False, 'firstName': 'Catherine', 'lastName': 'C', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/75942280-BMK05TR01MNL4NHK.jpg'}}, {'id': '98683884', 'isSanctioned': False, 'firstName': 'Matt', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/98683884-1MJ0OTISTPZWSBRJ.jpg'}}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '98683884', 'isSanctioned': False, 'firstName': 'Matt', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/98683884-1MJ0OTISTPZWSBRJ.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/bmRo9r', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 86, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 86, 'items': [{'id': '5129f550e4b0e1bb9e5bd6d4', 'name': 'Eats: Hong Kong (香港美食）', 'description': 'A gourmet paradise where food is in abundance, affordable, appetising. This is my personal list of food places in the territory that I recommend or plan  ...
#                          ID                          Name  Likes  Rating  Tips
# 0  4bb2cdfb715eef3b41bf85bb  Trusty Congee King (靠得住粥麵小館)     30     7.5    17
# ( 2 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa5010c0d71e67f1c568a58'}, 'response': {'venue': {'id': '4d400e3789616dcb823f00b5', 'name': 'Nice Capital Restaurant (麗都讌客)', 'contact': {'phone': '+85226289201', 'formattedPhone': '+852 2628 9201'}, 'location': {'address': 'Shop 130-133 & 135, 1/F, Citywalk 2, 18 Yeung Uk Rd', 'lat': 22.368597080747996, 'lng': 114.11409891159232, 'labeledLatLngs': [{'label': 'display', 'lat': 22.368597080747996, 'lng': 114.11409891159232}], 'cc': 'HK', 'city': 'Tsuen Wan', 'state': 'Tsuen Wan District', 'country': '香港', 'formattedAddress': ['Shop 130-133 & 135, 1/F, Citywalk 2, 18 Yeung Uk Rd', 'Tsuen Wan District', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/nice-capital/4d400e3789616dcb823f00b5', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1f5931735', 'name': 'Dim Sum Restaurant', 'pluralName': 'Dim Sum Restaurants', 'shortName': 'Dim Sum', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 2}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 6, 'groups': [{'type': 'others', 'count': 6, 'items': [{'id': '51215999', 'isSanctioned': False, 'firstName': 'anna.', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/51215999-LFFFCGW3L2JJO2FH.jpg'}}, {'id': '4618448', 'isSanctioned': False, 'firstName': 'Felix', 'lastName': 'N', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/5EYFT1DKCBZN31PH.jpg'}}, {'id': '1046444', 'isSanctioned': False, 'firstName': '蒙兀ナイト', 'lastName': 'K', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/1046444-FSAE50OP5QSCYMA4.jpg'}}, {'id': '71867061', 'isSanctioned': False, 'firstName': 'Мөнхбадрах', 'lastName': 'И', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/71867061-422AS1FCCYPG3MB3.jpg'}}]}], 'summary': '6 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.6, 'ratingColor': 'FFC800', 'ratingSignals': 9, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 60, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 60, 'items': [{'id': '50548613e4b0359ed57ba3b3', 'createdAt': 1347716627, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/3110455_CekF2CwZlgjjhUSAFukA_xMSgOYbqiWa-yNOFreGKyg.jpg', 'width': 537, 'height': 720, 'user': {'id': '3110455', 'isSanctioned': False, 'firstName': 'Maurice', 'lastName': 'L', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/JJAD5PJDOISCKDFV.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1296043575, 'tips': {'count': 2, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 2, 'items': [{'id': '54963d12498e7b8d394607cf', 'createdAt': 1419132178, 'text': '呢度兩間麗都嘅服務態度都超差！', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/54963d12498e7b8d394607cf', 'lang': 'zh', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '3533279', 'isSanctioned': False, 'firstName': 'N', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/O30VMPMK0CS0IXMU.jpg'}}}]}]}, 'shortUrl': 'http://4sq.com/h3p6iO', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 2, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 2, 'items': [{'id': '5646cad2498ed972ebfbe3e9', 'name': 'hong kong', 'description': '', 'type': 'others', 'user': {'id': '493 ...
#                          ID                            Name  Likes  Rating  \
# 0  4d400e3789616dcb823f00b5  Nice Capital Restaurant (麗都讌客)      6     6.6
#
#    Tips
# 0     2
# ( 3 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa5010c418d9541e77a2ec3'}, 'response': {'venue': {'id': '4be40308b02ec9b684c450c0', 'name': 'Sportful Garden Restaurant (陶源酒家)', 'contact': {'phone': '+85224009188', 'formattedPhone': '+852 2400 9188'}, 'location': {'address': 'Shop 312, 3/F, Nina Tower, 8 Yeung Uk Rd', 'lat': 22.3688089090423, 'lng': 114.11301612854004, 'labeledLatLngs': [{'label': 'display', 'lat': 22.3688089090423, 'lng': 114.11301612854004}], 'cc': 'HK', 'city': 'Tsuen Wan', 'state': 'Tsuen Wan District', 'country': '香港', 'formattedAddress': ['Shop 312, 3/F, Nina Tower, 8 Yeung Uk Rd', 'Tsuen Wan District', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/sportful-garden-restaurant-%E9%99%B6%E6%BA%90%E9%85%92%E5%AE%B6/4be40308b02ec9b684c450c0', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1f5931735', 'name': 'Dim Sum Restaurant', 'pluralName': 'Dim Sum Restaurants', 'shortName': 'Dim Sum', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 4}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 6, 'groups': [{'type': 'others', 'count': 6, 'items': [{'id': '66665721', 'isSanctioned': False, 'firstName': 'Brian', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/66665721-4XWKKS1XMLB42MBI.jpg'}}, {'id': '63206', 'isSanctioned': False, 'firstName': 'Lawrence', 'lastName': 'L', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/63206_1258678104554.jpg'}}, {'id': '43609851', 'isSanctioned': False, 'firstName': 'John', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/43609851_LOoGTu99_rfRXoDXH0uJ5WrU2db2zsDzgL4qzgwTpBF7f4nTXTtnXT5QH2AolD0MtDqz9hN16.jpg'}}, {'id': '49243985', 'isSanctioned': False, 'firstName': 'Cherry', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/49243985-WON3CILUXRALPYYZ.jpg'}}]}], 'summary': '6 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.2, 'ratingColor': 'FFC800', 'ratingSignals': 11, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 26, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 26, 'items': [{'id': '59210af8356b495a1fc3f9b9', 'createdAt': 1495337720, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/188825932_vad9yoIsCk3797MAw3lOFE7YD7SMiAhVV8yh7JsZNBs.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '188825932', 'isSanctioned': False, 'firstName': 'Windsor', 'lastName': 'L', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/188825932-VTORPZWIKOB5KBXF.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1273234184, 'tips': {'count': 4, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 4, 'items': [{'id': '51a18b77498e1de14a0515d7', 'createdAt': 1369541495, 'text': '例湯同鮑汁雞腳都係必食，一坐低就叫左先^^', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51a18b77498e1de14a0515d7', 'lang': 'zh', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '141412', 'isSanctioned': False, 'firstName': 'sidxx', 'lastName': 'w', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/FYY3V1D3O5UPJO4H.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/dBQEN9', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 3, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count':  ...
#                          ID                               Name  Likes  Rating  \
# 0  4be40308b02ec9b684c450c0  Sportful Garden Restaurant (陶源酒家)      6     6.2
#
#    Tips
# 0     4
# ( 4 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa5010c3f73b97916436b65'}, 'response': {'venue': {'id': '4e33f15062e1733d7aa708c4', 'name': 'The Great Restaurant (一品雞煲火鍋)', 'contact': {'phone': '+85224993337', 'formattedPhone': '+852 2499 3337', 'facebook': '511267855563077', 'facebookUsername': 'greatrestaurantchickenpot', 'facebookName': '一品雞煲火鍋'}, 'location': {'address': '73 Chung On St', 'lat': 22.36952513314385, 'lng': 114.1159987886162, 'labeledLatLngs': [{'label': 'display', 'lat': 22.36952513314385, 'lng': 114.1159987886162}], 'cc': 'HK', 'city': 'Tsuen Wan', 'state': 'Tsuen Wan District', 'country': '香港', 'formattedAddress': ['73 Chung On St', 'Tsuen Wan District', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/the-great-restaurant/4e33f15062e1733d7aa708c4', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 3}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 13, 'groups': [{'type': 'others', 'count': 13, 'items': []}], 'summary': '13 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.2, 'ratingColor': 'FFC800', 'ratingSignals': 20, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 77, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 77, 'items': [{'id': '56d973d8498e9bfed38cb949', 'createdAt': 1457091544, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/24303710_huEzFla4wqxaZmUQmeGFh_GbDLwd2gztOVv8b1XMD7g.jpg', 'width': 540, 'height': 960, 'user': {'id': '24303710', 'isSanctioned': False, 'firstName': 'Winnie', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/OXH3K4CYFDVSHKNP.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1312026960, 'tips': {'count': 3, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 3, 'items': [{'id': '4fafbe0de4b0e047b274f516', 'createdAt': 1336917517, 'text': '好味！記得叫手打丸\uf44d', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4fafbe0de4b0e047b274f516', 'lang': 'zh', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '63206', 'isSanctioned': False, 'firstName': 'Lawrence', 'lastName': 'L', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/63206_1258678104554.jpg'}}, {'id': '1164196', 'isSanctioned': False, 'firstName': 'Kenneth', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/I2N34QWZDYMJ11BV.jpg'}}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '27590039', 'isSanctioned': False, 'firstName': 'Anne', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/PRTX2J2PC5JZ2IIO.jpg'}}}]}]}, 'shortUrl': 'http://4sq.com/nuwkMU', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 9, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 9, 'items': [{'id': '54b9c162498e5005a083c42c', 'name': 'Hong Kong', 'description': '', 'type': 'others', 'user': {'id': '1648777', 'isSanctioned': False, 'firstName': 'Kylie', 'lastName': 'T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/NSVGJYQJPIXALDJX.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/1648777/list/hong-kong', 'canonicalUrl': 'https://foursquare.com/user/1648777/list/hong-kong', 'createdAt': 1421459810, 'updatedAt': 1551355720, 'followers': {'count': 0}, 'listItems': {'count': 109, 'items': [{'id': 'v4e33f15062e1733d7aa708c4', 'createdAt': 14309255 ...
#                          ID                           Name  Likes  Rating  \
# 0  4e33f15062e1733d7aa708c4  The Great Restaurant (一品雞煲火鍋)     13     6.2
#
#    Tips
# 0     3
# ( 5 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa5010d395e5f0683a42184'}, 'response': {'venue': {'id': '4d16c7aab15cb1f737efaf21', 'name': 'Super Super 一粥麵', 'contact': {'phone': '+85225615107', 'formattedPhone': '+852 2561 5107', 'facebook': '198396903512054', 'facebookUsername': 'SuperSuper.CongeeAndNoodle', 'facebookName': '一粥麵'}, 'location': {'address': 'G/F, Fu Tung Plaza, 33 Tat Tung Rd', 'lat': 22.288509871678244, 'lng': 113.94174936778109, 'labeledLatLngs': [{'label': 'display', 'lat': 22.288509871678244, 'lng': 113.94174936778109}], 'cc': 'HK', 'neighborhood': 'Tung Chung', 'city': 'San Tung Chung Hang', 'country': '香港', 'formattedAddress': ['G/F, Fu Tung Plaza, 33 Tat Tung Rd', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/super-super-%E4%B8%80%E7%B2%A5%E9%BA%B5/4d16c7aab15cb1f737efaf21', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d1941735', 'name': 'Noodle House', 'pluralName': 'Noodle Houses', 'shortName': 'Noodles', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}}, {'id': '52af3a7c3cf9994f4e043bed', 'name': 'Cantonese Restaurant', 'pluralName': 'Cantonese Restaurants', 'shortName': 'Cantonese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 0}, 'url': 'http://www.supersuper.com.hk', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 7, 'groups': [{'type': 'others', 'count': 7, 'items': [{'id': '21914720', 'isSanctioned': False, 'firstName': 'Albert', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/A21MB4NVCFH3INJZ.jpg'}}, {'id': '22436413', 'isSanctioned': False, 'firstName': 'Eliás', 'lastName': 'D', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/FN3AZNF3LQ1HZ2BD.jpg'}}, {'id': '3726032', 'isSanctioned': False, 'firstName': 'Jinda', 'lastName': 'J', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/3726032-NLOK14T1Q5MUM1LQ.jpg'}}, {'id': '66981680', 'isSanctioned': False, 'firstName': 'Umair', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/66981680_tEc8UCvr_sLksax-rMCJR-aS3ULRSCjUMPujGcLcCNpePgrRFnFXw3jZU4zFCq5hK6G_uEvwA.jpg'}}]}], 'summary': '7 Likes'}, 'dislike': False, 'ok': False, 'rating': 5.6, 'ratingColor': 'FF9600', 'ratingSignals': 14, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 120, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 120, 'items': [{'id': '5128c62ce4b0ef7a95ddad32', 'createdAt': 1361626668, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4799872_kA4KQcPcipaQVO_VIeOmTdX7bpS8AdP0tN6dSNbnOp0.jpg', 'width': 960, 'height': 720, 'user': {'id': '4799872', 'isSanctioned': False, 'firstName': 'Jacky', 'lastName': 'Y', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/4799872-WBC0SPLPWVHKMXBG.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1293338538, 'tips': {'count': 0, 'groups': []}, 'shortUrl': 'http://4sq.com/h2JHgu', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 2, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 2, 'items': [{'id': '4efd8e73f9abd5b38e53f9ec', 'name': "D's Hong Kong Eateries List", 'description': "My list of Hong Kong's eateries.", 'type': 'others', 'user': {'id': '18856383', 'isSanctioned': False, 'firstName': 'Damien', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix ...
#                          ID             Name  Likes  Rating  Tips
# 0  4d16c7aab15cb1f737efaf21  Super Super 一粥麵      7     5.6     0
# ( 6 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa5010d90fd6244ff3cc573'}, 'response': {'venue': {'id': '4c936bcd1221b1f768cf19e2', 'name': 'Federal Palace (Federal Palace 聯邦皇宮)', 'contact': {'phone': '+85226260181', 'formattedPhone': '+852 2626 0181'}, 'location': {'address': 'Shop 255, 2/F, Citygate Outlets, 20 Tat Tung Rd', 'lat': 22.289023388945896, 'lng': 113.9409154126902, 'labeledLatLngs': [{'label': 'display', 'lat': 22.289023388945896, 'lng': 113.9409154126902}], 'cc': 'HK', 'city': '香港', 'country': '香港', 'formattedAddress': ['Shop 255, 2/F, Citygate Outlets, 20 Tat Tung Rd', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/federal-palace-%E8%81%AF%E9%82%A6%E7%9A%87%E5%AE%AE/4c936bcd1221b1f768cf19e2', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 22}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 36, 'groups': [{'type': 'others', 'count': 36, 'items': []}], 'summary': '36 Likes'}, 'dislike': False, 'ok': False, 'rating': 5.6, 'ratingColor': 'FF9600', 'ratingSignals': 72, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 220, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 220, 'items': [{'id': '511d99b9e4b0fa889a187e48', 'createdAt': 1360894393, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1178750_lJSXNWQPP4oe9RpWtaucGoJh_ka-DXe8Vo--K5filt8.jpg', 'width': 612, 'height': 612, 'user': {'id': '1178750', 'isSanctioned': False, 'firstName': 'Aik', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/1178750_k1acviw4_7bUXJzjGLIHBWSYVXUuT-dvgxrBJZRtG8RGr4sh_Qd9GV7pMqvCAMe1MU4t69PeG.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1284729805, 'tips': {'count': 22, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 22, 'items': [{'id': '4e145ec252b1695f992e4525', 'createdAt': 1309957826, 'text': 'ราดหน้า ซาลาเปาไส้ครีมอร่อย....เช็ครอบดีๆ ไปตอนใกล้หมดรอบ อาหารจะไม่ค่อยเหลือ', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4e145ec252b1695f992e4525', 'lang': 'th', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'id': '6831608', 'isSanctioned': False, 'firstName': 'Chadaphon', 'lastName': 'K', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/6831608-LNFAXHEBHLTEY31F.jpg'}}, {'id': '325049', 'isSanctioned': False, 'firstName': 'arjin', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/BIO1JBPLVPIBPQ4X.png'}}, {'id': '7979920', 'isSanctioned': False, 'firstName': '🅿UII_SIRINRAT', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/7979920-F0IFI54ROQBGVKYR.jpg'}}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '612313', 'isSanctioned': False, 'firstName': 'NungNing 🎀', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/612313_VOjzTN5q_MWCU5cJS2u5kEg2BYLAG0n7DFd86qWZH5vqNOPJMyq5lJAzoCwvwPPPog8Qlm8OB.jpg'}}}]}]}, 'shortUrl': 'http://4sq.com/a0z98q', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 12, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 12, 'items': [{'id': '4ebbeea6c2ee8fa7288321be', 'name': 'Favorite Food', 'description': '', 'type': 'others', 'user': {'id': '5959885', 'isSanctioned': False, 'firstName': 'Alan', 'lastName': 'H', 'photo': {'prefix': 'https://fastly.4sqi.net/img/ ...
#                          ID                                  Name  Likes  \
# 0  4c936bcd1221b1f768cf19e2  Federal Palace (Federal Palace 聯邦皇宮)     36
#
#    Rating  Tips
# 0     5.6    22
# ( 7 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa5010da106903c94af0871'}, 'response': {'venue': {'id': '5243fe4711d27f0bc9d8d08d', 'name': 'Old Cheng Du 老城都', 'contact': {}, 'location': {'address': 'Unit 261-270, Food Republic, 2/F, Citygate Outlets, 20 Tat Tung Rd', 'lat': 22.289111, 'lng': 113.940568, 'labeledLatLngs': [{'label': 'display', 'lat': 22.289111, 'lng': 113.940568}], 'cc': 'HK', 'city': 'San Tung Chung Hang', 'country': '香港', 'formattedAddress': ['Unit 261-270, Food Republic, 2/F, Citygate Outlets, 20 Tat Tung Rd', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/old-cheng-du-%E8%80%81%E5%9F%8E%E9%83%BD/5243fe4711d27f0bc9d8d08d', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 1}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '6327802', 'isSanctioned': False, 'firstName': 'Alex', 'lastName': 'P', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/DJRSQWXBO5AFNTGM.jpg'}}, {'id': '46226181', 'isSanctioned': False, 'firstName': 'Владимир', 'lastName': 'Ч', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/46226181-GX3L5IOLLQB45SZB.jpg'}}]}], 'summary': '2 Likes'}, 'dislike': False, 'ok': False, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 9, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 9, 'items': [{'id': '57cfb7bd498e656cf295ae0c', 'createdAt': 1473230781, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/151008_4xYbQPKMkzHI_jWC7WFo3OOvc1l7PukXwxgt6DEA7iI.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '151008', 'isSanctioned': False, 'firstName': 'RG', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/VAKQWUVHDBFSOCHS.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1380187719, 'tips': {'count': 1, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 1, 'items': [{'id': '56a50002498e77efcd1a7d6c', 'createdAt': 1453654018, 'text': 'Huge portion of tomato soup - 2 liters, not less. Quiet place in a very crowded food court.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/56a50002498e77efcd1a7d6c', 'photo': {'id': '56a50005498ea4de43922e0d', 'createdAt': 1453654021, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/6327802_KH1bvWPu8U1badT6BcWcK5vjl0ZnjdZVLyPIrWm8fpI.jpg', 'width': 1440, 'height': 1440, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/6327802_KH1bvWPu8U1badT6BcWcK5vjl0ZnjdZVLyPIrWm8fpI.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '6327802', 'isSanctioned': False, 'firstName': 'Alex', 'lastName': 'P', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/DJRSQWXBO5AFNTGM.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/1h4293w', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 0, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 0, 'items': []}]}, 'seasonalHours': [], 'pageUpdates': {'count': 0, 'items': []}, 'inbox': {'count': 0, 'items': []}, 'attributes': {'groups': [{'type': 'price', 'name': 'Price', 'summary': '$', 'count': 1, 'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}]}, {'type': 'outdoorSeating', 'name': 'Outdoor Seating', 'summar ...
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 5243fe4711d27f0bc9d8d08d
# ( 8 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa5010d56c1c62a09bdebcd'}, 'response': {'venue': {'id': '4e89b10d6c25bf8636514f83', 'name': 'China House (家傳滬曉)', 'contact': {'phone': '+85226669100', 'formattedPhone': '+852 2666 9100', 'facebook': '243599905660452', 'facebookName': '家傳滬曉'}, 'location': {'address': 'Shop 201, 2/F, Tai Po Mega Mall (Zone B), 8 On Pong Rd', 'lat': 22.451397, 'lng': 114.16969, 'labeledLatLngs': [{'label': 'display', 'lat': 22.451397, 'lng': 114.16969}], 'cc': 'HK', 'neighborhood': 'Tai Po', 'city': 'Tai Po', 'state': 'Tai Po District', 'country': '香港', 'formattedAddress': ['Shop 201, 2/F, Tai Po Mega Mall (Zone B), 8 On Pong Rd', 'Tai Po District', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/china-house/4e89b10d6c25bf8636514f83', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 5}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': [{'id': '5271886', 'isSanctioned': False, 'firstName': 'Cathy', 'lastName': 'M', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/JQ54QHS4NBFZC2WS.jpg'}}, {'id': '1546647', 'isSanctioned': False, 'firstName': 'J', 'lastName': 'J', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/1546647_MfZqkU6j_2prPQpc5VhvnOVh8hU7xkQ7-eXiIidk53UlA2jo-Dc5ATB4PzWIBISMfpEbGj-Kg'}}, {'id': '42251748', 'isSanctioned': False, 'firstName': 'Jessica', 'lastName': 'K', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/42251748-SXT0NSLIXGEMKFLN.jpg'}}, {'id': '26963454', 'isSanctioned': False, 'firstName': 'Jody', 'lastName': 'C', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/OHF0ABIUTJ30GPZZ.jpg'}}]}], 'summary': '4 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.2, 'ratingColor': 'FFC800', 'ratingSignals': 8, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 29, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 29, 'items': [{'id': '509b9d84e4b09d90f553adf5', 'createdAt': 1352375684, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/885254_Mk1FrbFxF0seeDrb1gZKvzDh9DIbrorxMg5VXvHtvlU.jpg', 'width': 720, 'height': 537, 'user': {'id': '885254', 'isSanctioned': False, 'firstName': 'Tommy', 'lastName': 'W', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/1BBOYW2AZGS2RP33.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1317646605, 'tips': {'count': 5, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 5, 'items': [{'id': '532eb2d8498ecf1f7c057dc6', 'createdAt': 1395569368, 'text': 'Great Peking Duck and steamed Pork Dumpling, Sui Lung Bao', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/532eb2d8498ecf1f7c057dc6', 'photo': {'id': '532eb2e6498ee18764d9fce2', 'createdAt': 1395569382, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/26963454_KeMjbPq5ZD0MRWZxrxptDWVD-e9gaSwKl2CCGVlVCW8.jpg', 'width': 720, 'height': 960, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/26963454_KeMjbPq5ZD0MRWZxrxptDWVD-e9gaSwKl2CCGVlVCW8.jpg', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'id': '26963454', 'isSanctioned': False, 'firstName': 'Jody', 'lastName': 'C', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/OHF0ABIUTJ30GPZZ.jpg'}}]} ...
#                          ID                Name  Likes  Rating  Tips
# 0  4e89b10d6c25bf8636514f83  China House (家傳滬曉)      4     6.2     5
# ( 9 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa5010d74cc40265e8faf27'}, 'response': {'venue': {'id': '4bf0eb5fb315c9b6c97f93ff', 'name': 'Kwan Kee (群記清湯腩)', 'contact': {'phone': '+85226383071', 'formattedPhone': '+852 2638 3071'}, 'location': {'address': '26 Tai Ming Ln', 'lat': 22.44728216288752, 'lng': 114.16823789307782, 'labeledLatLngs': [{'label': 'display', 'lat': 22.44728216288752, 'lng': 114.16823789307782}], 'cc': 'HK', 'city': 'Tai Po', 'state': 'Tai Po District', 'country': '香港', 'formattedAddress': ['26 Tai Ming Ln', 'Tai Po District', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/kwan-kee/4bf0eb5fb315c9b6c97f93ff', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 11}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 7, 'groups': [{'type': 'others', 'count': 7, 'items': [{'id': '37184945', 'isSanctioned': False, 'firstName': 'Andrew', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/EJDEPMWZ3QEZEPCP.jpg'}}, {'id': '95874624', 'isSanctioned': False, 'firstName': 'Angela', 'lastName': 'L', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/95874624-F2RQZLSXLSFA4JIA.jpg'}}, {'id': '92486045', 'isSanctioned': False, 'firstName': 'King', 'lastName': 'F', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}, {'id': '484451', 'isSanctioned': False, 'firstName': 'Shawn', 'lastName': 'W', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/blank_boy.png', 'default': True}}]}], 'summary': '7 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.1, 'ratingColor': 'FFC800', 'ratingSignals': 15, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 35, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 35, 'items': [{'id': '5c8363b54940bc002c491067', 'createdAt': 1552114613, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/10153619_gRhUmSiQDGEj8GUNZ9msmmUccT0RknRo3-ffTxFNmXo.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '10153619', 'isSanctioned': False, 'firstName': 'JaNice', 'lastName': 'L', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/10153619_-3PS3e7f_g-b7LYt4L7MDfHSLuoQHpJ8Ap31SFv1hoLqA8JW1EbZMXjZHds6SRWBy0alJxWL4.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1274080095, 'tips': {'count': 11, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 11, 'items': [{'id': '56c18250498e6101b5a93c51', 'createdAt': 1455522384, 'text': 'If you come too late, you can only order sole skirt steak !', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/56c18250498e6101b5a93c51', 'photo': {'id': '56c18250498e6101b5a93c50', 'createdAt': 1455522384, 'source': {'name': 'Foursquare for BlackBerry', 'url': 'https://foursquare.com/download/#/blackberry'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/87874967_IwRUome5_-gPz8LiMpke0mQXSHUHVIWgNdDANWtY9P0.jpg', 'width': 640, 'height': 480, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/87874967_IwRUome5_-gPz8LiMpke0mQXSHUHVIWgNdDANWtY9P0.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '87874967', 'isSanctioned': False, 'firstName': 'Ivan', 'lastName': 'N', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/87874967-WTTBAWJNPIBVTZD4.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shor ...
#                          ID              Name  Likes  Rating  Tips
# 0  4bf0eb5fb315c9b6c97f93ff  Kwan Kee (群記清湯腩)      7     6.1    11
# ( 10 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa5010ddb499437289d6bc9'}, 'response': {'venue': {'id': '4d06140e37036dcb43ff19fb', 'name': 'Tong Kee Bao Dim 唐記包點', 'contact': {}, 'location': {'address': '96 Kwong Fuk Rd.', 'lat': 22.448277469619658, 'lng': 114.16751325130463, 'labeledLatLngs': [{'label': 'display', 'lat': 22.448277469619658, 'lng': 114.16751325130463}], 'cc': 'HK', 'city': 'Tai Po', 'state': 'Tai Po District', 'country': '香港', 'formattedAddress': ['96 Kwong Fuk Rd.', 'Tai Po District', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/tong-kee-bao-dim-%E5%94%90%E8%A8%98%E5%8C%85%E9%BB%9E/4d06140e37036dcb43ff19fb', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d16a941735', 'name': 'Bakery', 'pluralName': 'Bakeries', 'shortName': 'Bakery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 0}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 0, 'groups': []}, 'dislike': False, 'ok': False, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 3, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 3, 'items': [{'id': '56be87abcd10422b26a15877', 'createdAt': 1455327147, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/104163253_41pr33C2eSBhv6oKruDvgjDyDpgi_CNG1klJXamlehE.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '104163253', 'isSanctioned': False, 'firstName': 'KC', 'lastName': 'K', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/104163253-IB3YNOTUKMSDLMNH.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1292243982, 'tips': {'count': 0, 'groups': []}, 'shortUrl': 'http://4sq.com/fCEvhq', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 0, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 0, 'items': []}]}, 'seasonalHours': [], 'pageUpdates': {'count': 0, 'items': []}, 'inbox': {'count': 0, 'items': []}, 'attributes': {'groups': [{'type': 'price', 'name': 'Price', 'summary': '$', 'count': 1, 'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}]}, {'type': 'outdoorSeating', 'name': 'Outdoor Seating', 'count': 1, 'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]}]}, 'bestPhoto': {'id': '56be87abcd10422b26a15877', 'createdAt': 1455327147, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/104163253_41pr33C2eSBhv6oKruDvgjDyDpgi_CNG1klJXamlehE.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}}}}
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4d06140e37036dcb43ff19fb
# ( 11 / 26 ) processed
# ...
#                          ID                     Name  Likes  Rating  Tips
# 0  4b0588d8f964a520d5dc22e3  One Harbour Road (港灣壹號)     40     8.7    17
# ( 23 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa501109d7cfa6c1b41965e'}, 'response': {'venue': {'id': '4b67b864f964a520f15b2be3', 'name': 'Liu Yuan Pavilion (留園雅敘)', 'contact': {'phone': '+85228042000', 'formattedPhone': '+852 2804 2000'}, 'location': {'address': '3/F, The Broadway, 54-62 Lockhart Rd', 'lat': 22.278207847994896, 'lng': 114.1708592923482, 'labeledLatLngs': [{'label': 'display', 'lat': 22.278207847994896, 'lng': 114.1708592923482}], 'cc': 'HK', 'neighborhood': 'Wan Chai', 'city': '灣仔', 'state': '灣仔區', 'country': '香港', 'formattedAddress': ['3/F, The Broadway, 54-62 Lockhart Rd', '灣仔區', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/liu-yuan-pavilion/4b67b864f964a520f15b2be3', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 24}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 35, 'groups': [{'type': 'others', 'count': 35, 'items': []}], 'summary': '35 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.2, 'ratingColor': '73CF42', 'ratingSignals': 59, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 171, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 171, 'items': [{'id': '50c343ebe4b0de89d000a836', 'createdAt': 1354974187, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4250146_mUyWNY10PcxlfAlG31mqa2ICmrbAutDDcZEFm_qNFpM.jpg', 'width': 675, 'height': 720, 'user': {'id': '4250146', 'isSanctioned': False, 'firstName': 'ju', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/UODUC2NMTKJOH5YT.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1265088612, 'tips': {'count': 24, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 24, 'items': [{'id': '525e32a5498e3979565e6d76', 'createdAt': 1381905061, 'text': 'Probably best Xiao Lung Bao outside of Din Tai Fung and quietest Chinese restaurant in HK with a more modern layout.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/525e32a5498e3979565e6d76', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'id': '4242981', 'isSanctioned': False, 'firstName': 'Tagu', 'lastName': 'H', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/GHN02D2JCKGK41B2.jpg'}}, {'id': '1104799', 'isSanctioned': False, 'firstName': 'Stephen', 'lastName': 'F', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/HD1F1CDHHADFINOR.png'}}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '20563', 'isSanctioned': False, 'firstName': 'Casey', 'lastName': 'L', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/XEI5YTCXK2HRJSSM.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/a6nBsN', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 83, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 83, 'items': [{'id': '510cdbdde4b036b55595bf9a', 'name': 'HK - Resto to Try (HK Island)', 'description': "Restaurants on HK Island side can't wait to try! Bon Appétit :) Read my restaurant reviews on www.foodcraver.hk", 'entities': [{'indices': [94, 111], 'type': 'url', 'object': {'url': 'http://www.foodcraver.hk'}}], 'type': 'others', 'user': {'id': '12005011', 'isSanctioned': False, 'firstName': 'Food', 'lastName': 'C', 'photo': {'prefix': 'https://fastly.4sqi.net/img/u ...
#                          ID                      Name  Likes  Rating  Tips
# 0  4b67b864f964a520f15b2be3  Liu Yuan Pavilion (留園雅敘)     35     8.2    24
# ( 24 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa5011063aa2b1b7b47e8c9'}, 'response': {'venue': {'id': '4cda99864006a14382a4d2b2', 'name': 'Shia Wong Hip (蛇王協)', 'contact': {}, 'location': {'address': '170 Apliu St', 'lat': 22.3298, 'lng': 114.1627, 'labeledLatLngs': [{'label': 'display', 'lat': 22.3298, 'lng': 114.1627}], 'cc': 'HK', 'neighborhood': 'Sham Shui Po', 'city': '深水埗區', 'state': 'Sham Shui Po', 'country': '香港', 'formattedAddress': ['170 Apliu St', 'Sham Shui Po', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/shia-wong-hip/4cda99864006a14382a4d2b2', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1dd931735', 'name': 'Soup Place', 'pluralName': 'Soup Places', 'shortName': 'Soup', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/soup_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 8}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 10, 'groups': [{'type': 'others', 'count': 10, 'items': []}], 'summary': '10 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 17, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 70, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 70, 'items': [{'id': '4f3887b5e4b053246a5fadf1', 'createdAt': 1329104821, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/lw5oGYo-bv-vT-jEhsVBZuSZgXnGYTJ1YZ4-nMVnvXI.jpg', 'width': 720, 'height': 507, 'user': {'id': '1863759', 'isSanctioned': False, 'firstName': 'Robert', 'lastName': 'D', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/KXV30J3CN1WE01MC.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1289394566, 'tips': {'count': 8, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 8, 'items': [{'id': '585fe0de8cfe5449334f9e4a', 'createdAt': 1482678494, 'text': 'Lots of ingredients', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/585fe0de8cfe5449334f9e4a', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '59369886', 'isSanctioned': False, 'firstName': 'J', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/59369886_XYz2AZYG_iPrqPcc2FzMI_zT0mPalNfHl3d-Ru8qZKWLOyVngENMAWPT5lGswOXS6nDsBtXtS.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/bTFgXc', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 13, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 13, 'items': [{'id': '5365ad5e498ea672b0b16b58', 'name': '旅先で立ち寄りたいお店', 'description': '', 'type': 'others', 'user': {'id': '20173790', 'isSanctioned': False, 'firstName': 'あおば', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/20173790_zLrvii1k_KS7CgROoz9u7MN65-OvzudK4gRv3SBjik-wi0ul5VVaTtejwjyLOnIWmo3Po7oFm.jpg'}}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/cebu622/list/%E6%97%85%E5%85%88%E3%81%A7%E7%AB%8B%E3%81%A1%E5%AF%84%E3%82%8A%E3%81%9F%E3%81%84%E3%81%8A%E5%BA%97', 'canonicalUrl': 'https://foursquare.com/cebu622/list/%E6%97%85%E5%85%88%E3%81%A7%E7%AB%8B%E3%81%A1%E5%AF%84%E3%82%8A%E3%81%9F%E3%81%84%E3%81%8A%E5%BA%97', 'createdAt': 1399172446, 'updatedAt': 1595528146, 'photo': {'id': '545dca27498ebf6eca86e524', 'createdAt': 1415432743, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/53157600_AvE5lQ-3a8yB0-_r_YApjH6uWVzoDW-_H6xsQ-UMEcs.jpg', 'width': 960, 'height': 720, 'user': {'id': '5 ...
#                          ID                 Name  Likes  Rating  Tips
# 0  4cda99864006a14382a4d2b2  Shia Wong Hip (蛇王協)     10     7.5     8
# ( 25 / 26 ) processed
# {'meta': {'code': 200, 'requestId': '5fa50110465445080803b2d0'}, 'response': {'venue': {'id': '50dd8548e4b021301ef05370', 'name': '利星海鮮小炒火鍋', 'contact': {'phone': '+85223863381', 'formattedPhone': '+852 2386 3381'}, 'location': {'address': 'G/F, 151 Fuk Wa St', 'lat': 22.331472, 'lng': 114.162486, 'labeledLatLngs': [{'label': 'display', 'lat': 22.331472, 'lng': 114.162486}], 'cc': 'HK', 'city': '香港', 'country': '香港', 'formattedAddress': ['G/F, 151 Fuk Wa St', '香港']}, 'canonicalUrl': 'https://foursquare.com/v/%E5%88%A9%E6%98%9F%E6%B5%B7%E9%AE%AE%E5%B0%8F%E7%82%92%E7%81%AB%E9%8D%8B/50dd8548e4b021301ef05370', 'categories': [{'id': '4bf58dd8d48988d145941735', 'name': 'Chinese Restaurant', 'pluralName': 'Chinese Restaurants', 'shortName': 'Chinese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 1}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': [{'id': '379154487', 'isSanctioned': False, 'firstName': 'S.T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/379154487_SOE3EehQ_o9cpmqqPisNi0xiInHOtRRG8HXSue2GoSzgNsJchDhhGvVI3SL4n2eeLORm2meis.jpg'}}, {'id': '12079317', 'isSanctioned': False, 'firstName': 'Lui', 'lastName': 'S', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/ZFNWFW2ZSV4WQOVU.jpg'}}, {'id': '2667027', 'isSanctioned': False, 'firstName': 'u.point', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/2667027-EGHXDAQBNBACJ5ZM.jpg'}}, {'id': '46520980', 'isSanctioned': False, 'firstName': 'Benny', 'lastName': 'L', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/BGHSISQBMB5KRU3G.jpg'}}]}], 'summary': '4 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.2, 'ratingColor': 'FFC800', 'ratingSignals': 8, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 25, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 25, 'items': [{'id': '5cb294f82a7ab6002c00ca9b', 'createdAt': 1555207416, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/73320747_X55Fkg6qszXMpeWjJPJXkUUAN-tTzGH7Dgx2KJ3Dyqs.jpg', 'width': 1440, 'height': 1920, 'user': {'id': '73320747', 'isSanctioned': False, 'firstName': 'Esther', 'lastName': 'C', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/73320747-BJQTNEEVWTW00K5G.jpg'}}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1356694856, 'tips': {'count': 1, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 1, 'items': [{'id': '598dba34c530931ff5c0202e', 'createdAt': 1502460468, 'text': 'Everything is good! Staff are so friendly and helpful. All the food is served extremely hot and fresh. No ripe off, price are clearly marked. Highly recommended.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/598dba34c530931ff5c0202e', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'id': '379154487', 'isSanctioned': False, 'firstName': 'S.T', 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/', 'suffix': '/379154487_SOE3EehQ_o9cpmqqPisNi0xiInHOtRRG8HXSue2GoSzgNsJchDhhGvVI3SL4n2eeLORm2meis.jpg'}}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/TtW334', 'timeZone': 'Asia/Hong_Kong', 'listed': {'count': 1, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 1, 'items': [{'id': '51bd89a3498e9339ace39f6b', 'name': 'Hong Kong to-eat', 'description': 'My own to-eat restaurants in HK', 'type': 'others', 'user': {'id': '63206', 'isSanctioned': False, 'firstName': 'Lawrence', 'lastName': 'L', ...
#                          ID      Name  Likes  Rating  Tips
# 0  50dd8548e4b021301ef05370  利星海鮮小炒火鍋      4     6.2     1
# ( 26 / 26 ) processed
#             City                        ID                      Name Likes  \
# 21       Central  4b91df7ef964a520eedc33e3     Cuisine Cuisine (國金軒)    41
# 22      Wan Chai  4b0588d8f964a520d5dc22e3   One Harbour Road (港灣壹號)    40
# 23      Wan Chai  4b67b864f964a520f15b2be3  Liu Yuan Pavilion (留園雅敘)    35
# 24  Sham Shui Po  4cda99864006a14382a4d2b2       Shia Wong Hip (蛇王協)    10
# 25  Sham Shui Po  50dd8548e4b021301ef05370                  利星海鮮小炒火鍋     4
#
#     Rating Tips
# 21     7.2   20
# 22     8.7   17
# 23     8.2   24
# 24     7.5    8
# 25     6.2    1

# %%
chinese_rest_stats_hk.to_csv('chinese_rest_stats_hk.csv')

# %%
chinese_rest_stats_hk.shape
# Out:
# (26, 6)

# %%
chinese_rest_stats_hk.info()
chinese_rest_stats_hk = chinese_rest_stats_hk[chinese_rest_stats_hk.ID !=0]
chinese_rest_stats_hk['Likes'] = chinese_rest_stats_hk['Likes'].astype('float64')
chinese_rest_stats_hk['Tips'] = chinese_rest_stats_hk['Tips'].astype('float64')
chinese_rest_stats_hk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   City    26 non-null     object
#  1   ID      26 non-null     object
#  2   Name    26 non-null     object
#  3   Likes   26 non-null     object
#  4   Rating  26 non-null     float64
#  5   Tips    26 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 1.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 0 to 25
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   City    21 non-null     object
#  1   ID      21 non-null     object
#  2   Name    21 non-null     object
#  3   Likes   21 non-null     float64
#  4   Rating  21 non-null     float64
#  5   Tips    21 non-null     float64
# dtypes: float64(3), object(3)
# memory usage: 1.1+ KB

# %%
chinese_rest_stats_hk.describe()
# Out:
#             Likes     Rating       Tips
# count   21.000000  21.000000  21.000000
# mean    26.952381   6.828571  13.142857
# std     40.127891   1.046968  17.240318
# min      4.000000   5.600000   0.000000
# 25%      6.000000   5.900000   3.000000
# 50%     13.000000   6.200000   8.000000
# 75%     35.000000   7.900000  17.000000
# max    189.000000   8.700000  80.000000

# %%
# Resturant with maximum Likes
chinese_rest_stats_hk.loc[chinese_rest_stats_hk['Likes'].idxmax()]
# Out:
# City                       Central
# ID        51937957498e1228fa669b99
# Name             Duddell's (都爹利會館)
# Likes                          189
# Rating                         7.9
# Tips                            80
# Name: 20, dtype: object

# %%
# Resturant with maximum Likes
chinese_rest_stats_hk.loc[chinese_rest_stats_hk['Rating'].idxmax()]
# Out:
# City                      Wan Chai
# ID        4b0588d8f964a520d5dc22e3
# Name       One Harbour Road (港灣壹號)
# Likes                           40
# Rating                         8.7
# Tips                            17
# Name: 22, dtype: object

# %%
# Resturant with maximum Tips
chinese_rest_stats_hk.loc[chinese_rest_stats_hk['Tips'].idxmax()]
# Out:
# City                       Central
# ID        51937957498e1228fa669b99
# Name             Duddell's (都爹利會館)
# Likes                          189
# Rating                         7.9
# Tips                            80
# Name: 20, dtype: object

# %%
chinese_rest_stats_hk.head()
# Out:
#         City                        ID                               Name  \
# 0  Hong Kong  4b67b864f964a520f15b2be3           Liu Yuan Pavilion (留園雅敘)
# 1  Hong Kong  4bb2cdfb715eef3b41bf85bb       Trusty Congee King (靠得住粥麵小館)
# 2  Tsuen Wan  4d400e3789616dcb823f00b5     Nice Capital Restaurant (麗都讌客)
# 3  Tsuen Wan  4be40308b02ec9b684c450c0  Sportful Garden Restaurant (陶源酒家)
# 4  Tsuen Wan  4e33f15062e1733d7aa708c4      The Great Restaurant (一品雞煲火鍋)
#
#    Likes  Rating  Tips
# 0   35.0     8.2  24.0
# 1   30.0     7.5  17.0
# 2    6.0     6.6   2.0
# 3    6.0     6.2   4.0
# 4   13.0     6.2   3.0

# %%
hk_neighborhood_stats_rating=chinese_rest_stats_hk.groupby('City',as_index=False).mean()[['City','Rating','Likes','Tips']]
hk_neighborhood_stats_rating.columns=['City','Average Rating','Average Likes','Average Tips']
hk_neighborhood_stats_rating.sort_values(['Average Rating'],ascending=False).head(10)

hk_neighborhood_stats_rating
# Out:
#             City  Average Rating  Average Likes  Average Tips
# 0        Central        7.825000      74.250000         28.25
# 1      Hong Kong        7.850000      32.500000         20.50
# 2     Ngong Ping        5.900000      22.000000          8.00
# 3   Sham Shui Po        6.850000       7.000000          4.50
# 4          Tai O        5.800000       4.000000          2.00
# 5         Tai Po        6.150000       5.500000          8.00
# 6      Tsuen Wan        6.333333       8.333333          3.00
# 7     Tung Chung        5.600000      21.500000         11.00
# 8       Wan Chai        8.450000      37.500000         20.50
# 9  Yung Shue Wan        5.800000       5.000000          7.50

# %%
plt.figure(figsize=(10,5))
plt.title('Average rating of Chinese Restaurants for district')
plt.xlabel('District', fontsize = 15)
plt.ylabel('Average Rating', fontsize=15)
chinese_rest_stats_hk.groupby('City').mean()['Rating'].plot(kind='bar', color='lightblue')
plt.legend()
plt.show()

# %%
chinese_rest_stats_hk
# Out:
#              City                        ID  \
# 0       Hong Kong  4b67b864f964a520f15b2be3
# 1       Hong Kong  4bb2cdfb715eef3b41bf85bb
# 2       Tsuen Wan  4d400e3789616dcb823f00b5
# 3       Tsuen Wan  4be40308b02ec9b684c450c0
# 4       Tsuen Wan  4e33f15062e1733d7aa708c4
# 5      Tung Chung  4d16c7aab15cb1f737efaf21
# 6      Tung Chung  4c936bcd1221b1f768cf19e2
# 8          Tai Po  4e89b10d6c25bf8636514f83
# 9          Tai Po  4bf0eb5fb315c9b6c97f93ff
# 12  Yung Shue Wan  4bc307e84cdfc9b613be9621
# 13  Yung Shue Wan  4d4007211bd2a143b884ee7c
# 14     Ngong Ping  4c1b0402eac020a1f74744c2
# 16          Tai O  4cba94d4f50e224b6fecf4fb
# 18        Central  5288ad13498e14da0d2188fd
# 19        Central  5662695e498ee423e725baf7
# 20        Central  51937957498e1228fa669b99
# 21        Central  4b91df7ef964a520eedc33e3
# 22       Wan Chai  4b0588d8f964a520d5dc22e3
# 23       Wan Chai  4b67b864f964a520f15b2be3
# 24   Sham Shui Po  4cda99864006a14382a4d2b2
# 25   Sham Shui Po  50dd8548e4b021301ef05370
#
#                                     Name  Likes  Rating  Tips
# 0               Liu Yuan Pavilion (留園雅敘)   35.0     8.2  24.0
# 1           Trusty Congee King (靠得住粥麵小館)   30.0     7.5  17.0
# 2         Nice Capital Restaurant (麗都讌客)    6.0     6.6   2.0
# 3      Sportful Garden Restaurant (陶源酒家)    6.0     6.2   4.0
# 4          The Great Restaurant (一品雞煲火鍋)   13.0     6.2   3.0
# 5                        Super Super 一粥麵    7.0     5.6   0.0
# 6   Federal Palace (Federal Palace 聯邦皇宮)   36.0     5.6  22.0
# 8                     China House (家傳滬曉)    4.0     6.2   5.0
# 9                       Kwan Kee (群記清湯腩)    7.0     6.1  11.0
# 12         Lung Kong Restaurant (龍江川粵菜館)    6.0     5.8  10.0
# 13                                  蔡記小食    4.0     5.8   5.0
# 14   Ngong Ping Garden Restaurant (昂坪膳坊)   22.0     5.9   8.0
# 16       Fook Moon Lam Restaurant  福滿林酒樓    4.0     5.8   2.0
# 18                      China Tang (唐人館)   50.0     8.0  11.0
# 19               Howard's Gourmet (好酒好蔡)   17.0     8.2   2.0
# 20                     Duddell's (都爹利會館)  189.0     7.9  80.0
# 21                 Cuisine Cuisine (國金軒)   41.0     7.2  20.0
# 22               One Harbour Road (港灣壹號)   40.0     8.7  17.0
# 23              Liu Yuan Pavilion (留園雅敘)   35.0     8.2  24.0
# 24                   Shia Wong Hip (蛇王協)   10.0     7.5   8.0
# 25                              利星海鮮小炒火鍋    4.0     6.2   1.0

# %%
hk_neighborhood_stats=pd.merge(chinese_rest_stats_hk,myhk_df, on='City')
#hk_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]
hk_neighborhood_stats
# Out:
#              City                        ID  \
# 0       Hong Kong  4b67b864f964a520f15b2be3
# 1       Hong Kong  4bb2cdfb715eef3b41bf85bb
# 2       Tsuen Wan  4d400e3789616dcb823f00b5
# 3       Tsuen Wan  4be40308b02ec9b684c450c0
# 4       Tsuen Wan  4e33f15062e1733d7aa708c4
# 5      Tung Chung  4d16c7aab15cb1f737efaf21
# 6      Tung Chung  4c936bcd1221b1f768cf19e2
# 7          Tai Po  4e89b10d6c25bf8636514f83
# 8          Tai Po  4bf0eb5fb315c9b6c97f93ff
# 9   Yung Shue Wan  4bc307e84cdfc9b613be9621
# 10  Yung Shue Wan  4d4007211bd2a143b884ee7c
# 11     Ngong Ping  4c1b0402eac020a1f74744c2
# 12          Tai O  4cba94d4f50e224b6fecf4fb
# 13        Central  5288ad13498e14da0d2188fd
# 14        Central  5662695e498ee423e725baf7
# 15        Central  51937957498e1228fa669b99
# 16        Central  4b91df7ef964a520eedc33e3
# 17       Wan Chai  4b0588d8f964a520d5dc22e3
# 18       Wan Chai  4b67b864f964a520f15b2be3
# 19   Sham Shui Po  4cda99864006a14382a4d2b2
# 20   Sham Shui Po  50dd8548e4b021301ef05370
#
#                                     Name  Likes  Rating  Tips  \
# 0               Liu Yuan Pavilion (留園雅敘)   35.0     8.2  24.0
# 1           Trusty Congee King (靠得住粥麵小館)   30.0     7.5  17.0
# 2         Nice Capital Restaurant (麗都讌客)    6.0     6.6   2.0
# 3      Sportful Garden Restaurant (陶源酒家)    6.0     6.2   4.0
# 4          The Great Restaurant (一品雞煲火鍋)   13.0     6.2   3.0
# 5                        Super Super 一粥麵    7.0     5.6   0.0
# 6   Federal Palace (Federal Palace 聯邦皇宮)   36.0     5.6  22.0
# 7                     China House (家傳滬曉)    4.0     6.2   5.0
# 8                       Kwan Kee (群記清湯腩)    7.0     6.1  11.0
# 9          Lung Kong Restaurant (龍江川粵菜館)    6.0     5.8  10.0
# 10                                  蔡記小食    4.0     5.8   5.0
# 11   Ngong Ping Garden Restaurant (昂坪膳坊)   22.0     5.9   8.0
# 12       Fook Moon Lam Restaurant  福滿林酒樓    4.0     5.8   2.0
# 13                      China Tang (唐人館)   50.0     8.0  11.0
# 14               Howard's Gourmet (好酒好蔡)   17.0     8.2   2.0
# 15                     Duddell's (都爹利會館)  189.0     7.9  80.0
# 16                 Cuisine Cuisine (國金軒)   41.0     7.2  20.0
# 17               One Harbour Road (港灣壹號)   40.0     8.7  17.0
# 18              Liu Yuan Pavilion (留園雅敘)   35.0     8.2  24.0
# 19                   Shia Wong Hip (蛇王協)   10.0     7.5   8.0
# 20                              利星海鮮小炒火鍋    4.0     6.2   1.0
#
#             Coordinates  Latitude  Longitude
# 0   22.27832, 114.17469  22.27832  114.17469
# 1   22.27832, 114.17469  22.27832  114.17469
# 2   22.37137, 114.11329  22.37137  114.11329
# 3   22.37137, 114.11329  22.37137  114.11329
# 4   22.37137, 114.11329  22.37137  114.11329
# 5   22.28783, 113.94243  22.28783  113.94243
# 6   22.28783, 113.94243  22.28783  113.94243
# 7   22.45007, 114.16877  22.45007  114.16877
# 8   22.45007, 114.16877  22.45007  114.16877
# 9   22.22623, 114.11241  22.22623  114.11241
# 10  22.22623, 114.11241  22.22623  114.11241
# 11  22.25556, 113.90391  22.25556  113.90391
# 12  22.25515, 113.86309  22.25515  113.86309
# 13  22.28299, 114.15846  22.28299  114.15846
# 14  22.28299, 114.15846  22.28299  114.15846
# 15  22.28299, 114.15846  22.28299  114.15846
# 16  22.28299, 114.15846  22.28299  114.15846
# 17  22.28142, 114.17258  22.28142  114.17258
# 18  22.28142, 114.17258  22.28142  114.17258
# 19  22.33023, 114.15945  22.33023  114.15945
# 20  22.33023, 114.15945  22.33023  114.15945

# %%
address = 'Hong Kong'

geolocator = Nominatim(user_agent="hk_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Hong Kong are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Hong Kong are 22.350627, 114.1849161.

# %%
hk_neighborhood_stats_rating.head()
# Out:
#    Neighborhood  Average Rating  Average Likes  Average Tips  \
# 0       Central           7.825          74.25         28.25
# 1     Hong Kong           7.850          32.50         20.50
# 2    Ngong Ping           5.900          22.00          8.00
# 3  Sham Shui Po           6.850           7.00          4.50
# 4         Tai O           5.800           4.00          2.00
#
#                   Label
# 0      Central, (7.825)
# 1     Hong Kong, (7.85)
# 2     Ngong Ping, (5.9)
# 3  Sham Shui Po, (6.85)
# 4          Tai O, (5.8)

# %%
myhk_df2 =pd.merge(myhk_df,hk_neighborhood_stats_rating, on='City')
myhk_df2['Label']=myhk_df2['City']+', '+'('+ myhk_df2['Average Rating'].map(str)+')'
myhk_df2
# Out:
#             City          Coordinates  Latitude  Longitude  Average Rating  \
# 0      Hong Kong  22.27832, 114.17469  22.27832  114.17469        7.850000
# 1      Tsuen Wan  22.37137, 114.11329  22.37137  114.11329        6.333333
# 2     Tung Chung  22.28783, 113.94243  22.28783  113.94243        5.600000
# 3         Tai Po  22.45007, 114.16877  22.45007  114.16877        6.150000
# 4  Yung Shue Wan  22.22623, 114.11241  22.22623  114.11241        5.800000
# 5     Ngong Ping  22.25556, 113.90391  22.25556  113.90391        5.900000
# 6          Tai O  22.25515, 113.86309  22.25515  113.86309        5.800000
# 7        Central  22.28299, 114.15846  22.28299  114.15846        7.825000
# 8       Wan Chai  22.28142, 114.17258  22.28142  114.17258        8.450000
# 9   Sham Shui Po  22.33023, 114.15945  22.33023  114.15945        6.850000
#
#    Average Likes  Average Tips                           Label
# 0      32.500000         20.50               Hong Kong, (7.85)
# 1       8.333333          3.00  Tsuen Wan, (6.333333333333333)
# 2      21.500000         11.00               Tung Chung, (5.6)
# 3       5.500000          8.00                  Tai Po, (6.15)
# 4       5.000000          7.50            Yung Shue Wan, (5.8)
# 5      22.000000          8.00               Ngong Ping, (5.9)
# 6       4.000000          2.00                    Tai O, (5.8)
# 7      74.250000         28.25                Central, (7.825)
# 8      37.500000         20.50                Wan Chai, (8.45)
# 9       7.000000          4.50            Sham Shui Po, (6.85)

# %%
# create map
map_hk = folium.Map(location=[latitude, longitude], zoom_start=10.25)

for lat, lng, city,label in zip(myhk_df2['Latitude'],myhk_df2['Longitude'],myhk_df2['City'],myhk_df2['Label']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_hk)  
       
map_hk
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Result, Conclusion and Limitation
# In Hong Kong, Central and Wan Chai has relative high rate chinese restaurants in average. Duddell's (都爹利會館) and One Harbour Road (港灣壹號) obtains the highest number of likes and rating among the restaurants in Hong Kong, according to the database of Foursquares.
#
# To summarize, it would be great to have a visit to Central and Wanchai for good Chinese restaurants.
#
# As an investor, it would be a bit risky and competitive to start a Chinese restaurants in Central and Wan Chai without any experience. To have the best shot of success, it is suggested to open a Chinese restaurant in Tsuen Wan or Sham Shui Po. These districts have neighborhoods with average ratings exceeding 6.0 and less chinese restaurants than Central and Wanchai, making competition easier.
#
# To conclude, the above analysis is based on the limited resources and data from Foursquares, which is not fully explaining the distribution and performance of restaurants in Hong Kong. The accuracy of data from Foursquares would determine the value of this analysis. It is recommended to have a comprehensive research and analysis with more data from external databases.
